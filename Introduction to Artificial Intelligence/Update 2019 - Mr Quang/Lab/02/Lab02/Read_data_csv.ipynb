# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
from IPython.display import Image

OriginalCustomerChurn = pd.read_csv("CustomerChurn.csv")
OriginalBigMartSales = pd.read_csv("BigMartSales.csv")

# %%
(OriginalCustomerChurn.isnull().sum() / len(OriginalCustomerChurn))*100
# Out:
# State                     0.0
# Account length            0.0
# Area code                 0.0
# International plan        0.0
# Voice mail plan           0.0
# Number vmail messages     0.0
# Total day minutes         0.0
# Total day calls           0.0
# Total day charge          0.0
# Total eve minutes         0.0
# Total eve calls           0.0
# Total eve charge          0.0
# Total night minutes       0.0
# Total night calls         0.0
# Total night charge        0.0
# Total intl minutes        0.0
# Total intl calls          0.0
# Total intl charge         0.0
# Customer service calls    0.0
# Churn                     0.0
# dtype: float64

# %%
(OriginalBigMartSales.isnull().sum() / len(OriginalBigMartSales))*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
dataCustomerChurn = OriginalCustomerChurn.fillna(OriginalCustomerChurn.median())

# %%
dataBigMartSales = OriginalBigMartSales.fillna(OriginalBigMartSales.median())

# %%
dataBigMartSales['Outlet_Size'].fillna('UNKNOWN')
# Out:
# 0        Medium
# 1        Medium
# 2        Medium
# 3       UNKNOWN
# 4          High
# 5        Medium
# 6          High
# 7        Medium
# 8       UNKNOWN
# 9       UNKNOWN
# 10       Medium
# 11        Small
# 12       Medium
# 13        Small
# 14         High
# 15        Small
# 16       Medium
# 17       Medium
# 18       Medium
# 19        Small
# 20         High
# 21       Medium
# 22        Small
# 23        Small
# 24        Small
# 25      UNKNOWN
# 26        Small
# 27         High
# 28      UNKNOWN
# 29        Small
#          ...
# 8493    UNKNOWN
# 8494    UNKNOWN
# 8495      Small
# 8496    UNKNOWN
# 8497      Small
# 8498     Medium
# 8499      Small
# 8500    UNKNOWN
# 8501    UNKNOWN
# 8502    UNKNOWN
# 8503      Small
# 8504     Medium
# 8505     Medium
# 8506     Medium
# 8507      Small
# 8508    UNKNOWN
# 8509    UNKNOWN
# 8510      Small
# 8511     Medium
# 8512       High
# 8513      Small
# 8514    UNKNOWN
# 8515     Medium
# 8516     Medium
# ...

# %%
dataCustomerChurn.shape
# Out:
# (3333, 20)

# %%
dataBigMartSales.shape
# Out:
# (8523, 12)

# %%
dataBigMartSales.describe().loc[['mean','std']]
# Out:
#       Item_Weight  Item_Visibility    Item_MRP  Outlet_Establishment_Year  \
# mean     12.81342         0.066132  140.992782                1997.831867
# std       4.22724         0.051598   62.275067                   8.371760
#
#       Item_Outlet_Sales
# mean        2181.288914
# std         1706.499616

# %%
dataCustomerChurn.describe().loc[['mean','std']]
# Out:
#       Account length   Area code  Number vmail messages  Total day minutes  \
# mean      101.064806  437.182418               8.099010         179.775098
# std        39.822106   42.371290              13.688365          54.467389
#
#       Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# mean       100.435644         30.562307         200.980348       100.114311
# std         20.069084          9.259435          50.713844        19.922625
#
#       Total eve charge  Total night minutes  Total night calls  \
# mean         17.083540           200.872037         100.107711
# std           4.310668            50.573847          19.568609
#
#       Total night charge  Total intl minutes  Total intl calls  \
# mean            9.039325           10.237294          4.479448
# std             2.275873            2.791840          2.461214
#
#       Total intl charge  Customer service calls
# mean           2.764581                1.562856
# ...

# %%
sns.distplot(a=dataCustomerChurn['Total eve minutes'], color="red")
sns.distplot(a=dataCustomerChurn['Total night minutes'], color="green")

# %%
sns.jointplot("Total eve minutes", "Total night minutes", data=dataCustomerChurn, kind="reg")

# %%
dataCustomerChurn['State'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
dataCustomerChurn['State'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OR     78
# OH     78
# WI     78
# WY     77
# VA     77
# CT     74
# VT     73
# ID     73
# MI     73
# UT     72
# TX     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# NV     66
# CO     66
# WA     66
# MA     65
# MS     65
# RI     65
# AZ     64
# MO     63
# FL     63
# NM     62
# ND     62
# ME     62
# OK     61
# NE     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# DC     54
# GA     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
sns.catplot(data=dataCustomerChurn, kind='bar')
